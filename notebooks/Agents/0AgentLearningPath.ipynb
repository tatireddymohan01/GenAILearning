# %% [markdown]
# # Agents Learning Path (Start Here)
#
# Use this notebook as your entry point. Follow the sequence strictly from 1 to 9.
#
# ## Why this order?
#
# Each notebook fixes one limitation from the previous one:
#
# 1. `1LLMWithTools.ipynb` - manual loop
# 2. `2ReActAgent.ipynb` - framework-managed loop
# 3. `3ToolCallingAgent.ipynb` - native tool calling
# 4. `4StructuredOutputAgent.ipynb` - typed responses
# 5. `5ConversationalAgent.ipynb` - memory/history
# 6. `6RAGAgent.ipynb` - retrieval as a tool
# 7. `7MultiAgent_Router.ipynb` - specialization by router
# 8. `8PlanAndExecuteAgent.ipynb` - planning before execution
# 9. `9SelfCorrectingAgent.ipynb` - critic + retry loop
#
# Read the concept guide in parallel:
# - `Agents_Concepts.md`
#
# Shared helper module used by all notebooks:
# - `AgentUtils.py`

# %%
from AgentUtils import TEST_QUERIES

print("Standard test queries used across all notebooks:\n")
for i, query in enumerate(TEST_QUERIES, start=1):
    print(f"{i}. {query}")
# Out:
# Standard test queries used across all notebooks:
#
# 1. What is 144 divided by 12?
# 2. Search docs for: what is a LangChain agent?
# 3. What is the weather in Hyderabad?
# 4. Search docs for RAG and also calculate 25 multiplied by 4

# %% [markdown]
# ## Suggested Study Routine
#
# 1. Open one notebook.
# 2. Run every cell in order.
# 3. Compare tool usage behavior with previous notebook.
# 4. Ask: **what new capability was added, and what limitation still remains?**
# 5. Move to next notebook.
#
# Do not skip Notebook 1. It explains what agent frameworks automate.
